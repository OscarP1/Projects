# %% [markdown]
# # Quantitative Value Trading Strategy
# #### This program selects the 50 stocks with the best intrinsic value metrics and calculates the recommended trades for an equal-weighted portfolio of these stocks.

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import numpy as np
import pandas as pd
import xlsxwriter
import requests
from scipy.stats import percentileofscore as score
from statistics import mean
import math

# %%
stocks = pd.read_csv('CSV_files/sp_500_stocks.csv')
stocks = stocks[~stocks['Ticker'].isin(['DISCA', 'HFC','VIAC','WLTW'])]
stocks
# Out:
#     Ticker
# 0        A
# 1      AAL
# 2      AAP
# 3     AAPL
# 4     ABBV
# ..     ...
# 500    YUM
# 501    ZBH
# 502   ZBRA
# 503   ZION
# 504    ZTS
#
# [501 rows x 1 columns]

# %%
IEX_CLOUD_API_TOKEN = 'pk_682c76a7979e43349b214ad64d6d41b7'

# %%
def chunks(lst, n):
    """
    Yield successive n-sized chunks from lst.
    """
    for i in range(0, len(lst), n):
        yield lst[i:i + n]
symbol_groups = list(chunks(stocks['Ticker'], 100))
symbol_strings = []
for i in range(0, len(symbol_groups)):
    symbol_strings.append(','.join(symbol_groups[i]))
    
my_columns = ['Ticker', 'Price', 'Price-to-Earnings Ratio', 'Number of Shares to Buy']

# %% [markdown]
# ## First Value Strategy
# #### Low intrinsic value stocks are filtered out solely by Price-to-Earnings ratio.

# %%
final_dataframe = pd.DataFrame(columns = my_columns)

for symbol_string in symbol_strings:
    batch_api_call_url = f'https://cloud.iexapis.com/stable/stock/market/batch?symbols={symbol_string}&types=quote&token={IEX_CLOUD_API_TOKEN}'
    data = requests.get(batch_api_call_url).json()
    for symbol in symbol_string.split(','):
        final_dataframe = final_dataframe.append(
        pd.Series(
            [
                symbol,
                data[symbol]['quote']['latestPrice'],
                data[symbol]['quote']['peRatio'],
                'N/A'
            ],
            index = my_columns
        ),
            ignore_index = True
        )
final_dataframe
# Out:
#     Ticker   Price Price-to-Earnings Ratio Number of Shares to Buy
# 0        A  117.50                   25.88                     N/A
# 1      AAL   14.86                    3.46                     N/A
# 2      AAP   67.58                   10.04                     N/A
# 3     AAPL  177.07                   29.76                     N/A
# 4     ABBV  149.24                   30.64                     N/A
# ..     ...     ...                     ...                     ...
# 496    YUM  129.10                   26.08                     N/A
# 497    ZBH  115.17                   47.99                     N/A
# 498   ZBRA  269.25                   21.56                     N/A
# 499   ZION   33.03                    3.43                     N/A
# 500    ZTS  181.25                   38.16                     N/A
#
# [501 rows x 4 columns]

# %%
final_dataframe.sort_values('Price-to-Earnings Ratio', ascending = False, inplace = True)
final_dataframe = final_dataframe[final_dataframe['Price-to-Earnings Ratio'] > 0]
final_dataframe = final_dataframe[:50]
final_dataframe.reset_index(inplace = True)
final_dataframe.drop('index', axis = 1, inplace = True)

# %%
final_dataframe
# Out:
#    Ticker    Price Price-to-Earnings Ratio Number of Shares to Buy
# 0    WYNN   94.240                 1510.26                     N/A
# 1     LVS   52.960                   795.2                     N/A
# 2     CRM  206.200                  540.64                     N/A
# 3     TAP   62.415                  331.64                     N/A
# 4    WELL   79.945                  329.67                     N/A
# 5     KSU  293.590                  279.61                     N/A
# 6    NVDA  456.335                  237.67                     N/A
# 7     VTR   41.770                  218.46                     N/A
# 8     STE  222.405                  186.89                     N/A
# 9    DXCM  105.620                  126.28                     N/A
# 10    CLX  150.170                  125.14                     N/A
# 11   AMZN  134.130                  105.61                     N/A
# 12    DLR  123.420                   98.74                     N/A
# 13    TYL  373.800                   96.84                     N/A
# 14    MRK  108.200                   88.69                     N/A
# 15   EQIX  753.220                   86.88                     N/A
# 16   ALGN  351.740                   86.64                     N/A
# 17    CAH   85.510                   85.84                     N/A
# 18    AMT  175.830                   84.94                     N/A
# 19    BSX   50.280                   84.75                     N/A
# 20    NWS   21.045                   81.76                     N/A
# 21    NOW  560.270                    80.5                     N/A
# 22   NWSA   20.590                   79.99                     N/A
# 23    LLY  552.010                   76.77                     N/A
# 24    LYV   83.940                   75.62                     N/A
# 25   SNPS  434.850                   73.45                     N/A
# 26   ISRG  286.535                   71.99                     N/A
# 27   VRSK  232.060                   70.53                     N/A
# 28    DIS   85.445                   69.47                     N/A
# 29   CDNS  224.910                    69.2                     N/A
# 30   ABMD  381.020                   65.69                     N/A
# 31    IBM  141.870                   64.19                     N/A
# 32    COO  370.440                   63.87                     N/A
# 33    VFC   19.200                    63.7                     N/A
# 34   INTU  488.235                   61.88                     N/A
# 35   ALXN  182.500                   59.45                     N/A
# 36    VAR  177.070                   58.44                     N/A
# 37    WST  390.850                   56.98                     N/A
# 38    TSN   54.080                   56.75                     N/A
# 39    TIF  131.460                    55.7                     N/A
# 40    DUK   89.530                   54.59                     N/A
# 41   SPGI  383.730                   53.15                     N/A
# 42   PAYC  286.970                   52.75                     N/A
# 43    PWR  205.950                   52.67                     N/A
# 44    XYL   98.900                   52.61                     N/A
# 45   XLNX  194.920                   52.54                     N/A
# 46   ADSK  200.300                   51.89                     N/A
# 47   IDXX  486.590                   51.65                     N/A
# 48    CHD   92.840                   51.29                     N/A
# 49   ADBE  518.980                   49.57                     N/A

# %%
def portfolio_input():
    global portfolio_size
    portfolio_size = input('Enter the size of your portfolio:')
    
    try:
        float(portfolio_size)
    except ValueError:
        print('Please enter an integer.')
        portfolio_size = input('Enter the size of your portfolio:')
portfolio_input()
# Out:
# Enter the size of your portfolio: 1000000

# %%
position_size = float(portfolio_size)/len(final_dataframe.index)
for row in final_dataframe.index:
    final_dataframe.loc[row, 'Number of Shares to Buy'] = math.floor(position_size/final_dataframe.loc[row, 'Price'])
    
final_dataframe
# Out:
#    Ticker    Price Price-to-Earnings Ratio Number of Shares to Buy
# 0    WYNN   94.240                 1510.26                     212
# 1     LVS   52.960                   795.2                     377
# 2     CRM  206.200                  540.64                      96
# 3     TAP   62.415                  331.64                     320
# 4    WELL   79.945                  329.67                     250
# 5     KSU  293.590                  279.61                      68
# 6    NVDA  456.335                  237.67                      43
# 7     VTR   41.770                  218.46                     478
# 8     STE  222.405                  186.89                      89
# 9    DXCM  105.620                  126.28                     189
# 10    CLX  150.170                  125.14                     133
# 11   AMZN  134.130                  105.61                     149
# 12    DLR  123.420                   98.74                     162
# 13    TYL  373.800                   96.84                      53
# 14    MRK  108.200                   88.69                     184
# 15   EQIX  753.220                   86.88                      26
# 16   ALGN  351.740                   86.64                      56
# 17    CAH   85.510                   85.84                     233
# 18    AMT  175.830                   84.94                     113
# 19    BSX   50.280                   84.75                     397
# 20    NWS   21.045                   81.76                     950
# 21    NOW  560.270                    80.5                      35
# 22   NWSA   20.590                   79.99                     971
# 23    LLY  552.010                   76.77                      36
# 24    LYV   83.940                   75.62                     238
# 25   SNPS  434.850                   73.45                      45
# 26   ISRG  286.535                   71.99                      69
# 27   VRSK  232.060                   70.53                      86
# 28    DIS   85.445                   69.47                     234
# 29   CDNS  224.910                    69.2                      88
# 30   ABMD  381.020                   65.69                      52
# 31    IBM  141.870                   64.19                     140
# 32    COO  370.440                   63.87                      53
# 33    VFC   19.200                    63.7                    1041
# 34   INTU  488.235                   61.88                      40
# 35   ALXN  182.500                   59.45                     109
# 36    VAR  177.070                   58.44                     112
# 37    WST  390.850                   56.98                      51
# 38    TSN   54.080                   56.75                     369
# 39    TIF  131.460                    55.7                     152
# 40    DUK   89.530                   54.59                     223
# 41   SPGI  383.730                   53.15                      52
# 42   PAYC  286.970                   52.75                      69
# 43    PWR  205.950                   52.67                      97
# 44    XYL   98.900                   52.61                     202
# 45   XLNX  194.920                   52.54                     102
# 46   ADSK  200.300                   51.89                      99
# 47   IDXX  486.590                   51.65                      41
# 48    CHD   92.840                   51.29                     215
# 49   ADBE  518.980                   49.57                      38

# %% [markdown]
# ## Second Value Strategy
# #### This strategy filters out "glamour" stocks based on percentiles of Price-to-Earnings ratio, Price-to-Book ratio, Price-to-Sales ratio, EV/EBITDA, and EV/GP.

# %%
rv_columns = [
    'Ticker',
    'Price',
    'Number of Shares to Buy',
    'Price-to-Earnings ratio',
    'PE Percentile',
    'Price-to-Book Ratio',
    'PB Percentile',
    'Price-to-Sales Ratio',
    'PS Percentile',
    'EV/EBITDA',
    'EV/EBITDA Percentile',
    'EV/GP',
    'EV/GP Percentile',
    'RV Score'
]

rv_dataframe = pd.DataFrame(columns = my_columns)

# %%
for symbol_string in symbol_strings:
    batch_api_call_url = f'https://cloud.iexapis.com/stable/stock/market/batch?symbols={symbol_string}&types=quote,advanced-stats&token={IEX_CLOUD_API_TOKEN}'
    data = requests.get(batch_api_call_url).json()   
    for symbol in symbol_string.split(','):
        enterprise_value = data[symbol]['advanced-stats']['enterpriseValue']
        ebitda = data[symbol]['advanced-stats']['EBITDA']
        gross_profit = data[symbol]['advanced-stats']['grossProfit']
            
        try:
            ev_to_ebitda = enterprise_value/ebitda
        except TypeError:
            ev_to_ebitda = np.NaN

        try:
            ev_to_gross_profit = enterprise_value/gross_profit
        except TypeError:
            ev_to_gross_profit = np.NaN

        rv_dataframe = rv_dataframe.append(
            pd.Series([
                symbol,
                data[symbol]['quote']['latestPrice'],
                '0',
                data[symbol]['quote']['peRatio'],
                '0',
                data[symbol]['advanced-stats']['priceToBook'],
                '0',
                data[symbol]['advanced-stats']['priceToSales'],
                '0',
                ev_to_ebitda,
                '0',
                ev_to_gross_profit,
                '0',
                '0'
            ],
            index = rv_columns),  
            ignore_index = True)

# %%
rv_dataframe = rv_dataframe.drop('Price-to-Earnings Ratio', axis = 1)
rv_dataframe
# Out:
#     Ticker   Price Number of Shares to Buy  Price-to-Earnings ratio  \
# 0        A  117.68                       0                    25.92
# 1      AAL   14.85                       0                     3.46
# 2      AAP   67.44                       0                    10.02
# 3     AAPL  177.21                       0                    29.78
# 4     ABBV  148.78                       0                    30.55
# ..     ...     ...                     ...                      ...
# 496    YUM  129.08                       0                    26.08
# 497    ZBH  115.53                       0                    48.14
# 498   ZBRA  269.60                       0                    21.59
# 499   ZION   32.94                       0                     3.42
# 500    ZTS  181.72                       0                    38.26
#
#     PE Percentile  Price-to-Book Ratio PB Percentile  Price-to-Sales Ratio  \
# 0               0                 6.07             0                4.9900
# 1               0                -2.26             0                0.1873
# 2               0                 1.54             0                0.3620
# 3               0                45.61             0                7.1600
# 4               0                20.60             0                4.7300
# ..            ...                  ...           ...                   ...
# 496             0                -4.28             0                5.1600
# 497             0                 2.03             0                3.5000
# 498             0                 4.59             0                2.5000
# 499             0                 1.06             0                1.0900
# 500             0                18.00             0               10.1200
#
#     PS Percentile  EV/EBITDA EV/EBITDA Percentile      EV/GP EV/GP Percentile  \
# 0               0  18.499682                    0   9.541080                0
# 1               0   4.696440                    0   0.614247                0
# 2               0   6.424212                    0   1.162786                0
# 3               0  22.555575                    0  16.760511                0
# 4               0  11.491793                    0   8.218842                0
# ..            ...        ...                  ...        ...              ...
# 496             0  20.026384                    0   9.003282                0
# 497             0  16.083017                    0   5.917498                0
# 498             0  15.234695                    0   6.198576                0
# 499             0   2.744341                    0   1.142607                0
# 500             0  27.870221                    0  15.271354                0
#
#     RV Score
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 496        0
# 497        0
# 498        0
# 499        0
# 500        0
#
# [501 rows x 14 columns]

# %%
rv_dataframe[rv_dataframe.isnull().any(axis =1)]
# Out:
#     Ticker    Price Number of Shares to Buy  Price-to-Earnings ratio  \
# 6     ABMD  381.020                       0                    65.69
# 28    ALXN  182.500                       0                    59.45
# 40     AON  323.970                       0                      NaN
# 88    CERN   94.920                       0                    47.94
# 118    CTL   11.000                       0                     9.73
# 121   CTXS  103.900                       0                    39.96
# 135  DISCK   24.420                       0                      NaN
# 164   ETFC   49.260                       0                    14.27
# 183   FISV  114.230                       0                      NaN
# 185   FLIR   57.340                       0                    32.03
# 192    FRT   95.945                       0                      NaN
# 252      J  136.180                       0                      NaN
# 263    KIM   18.600                       0                      NaN
# 323   MXIM  103.140                       0                    33.82
# 324    MYL   15.855                       0                    30.76
# 325    NBL    8.450                       0                    -0.73
# 358   PBCT   19.410                       0                    13.96
# 380    PSA  273.165                       0                      NaN
# 408   SIVB  106.040                       0                     4.18
# 491   XLNX  194.920                       0                    52.54
#
#     PE Percentile  Price-to-Book Ratio PB Percentile  Price-to-Sales Ratio  \
# 6               0                  NaN             0                   NaN
# 28              0                  NaN             0                   NaN
# 40              0                  NaN             0                   NaN
# 88              0                  NaN             0                   NaN
# 118             0                  NaN             0                   NaN
# 121             0                  NaN             0                   NaN
# 135             0                  NaN             0                   NaN
# 164             0                  NaN             0                   NaN
# 183             0                  NaN             0                   NaN
# 185             0                  NaN             0                   NaN
# 192             0                  NaN             0                   NaN
# 252             0                  NaN             0                   NaN
# 263             0                  NaN             0                   NaN
# 323             0                  NaN             0                   NaN
# 324             0                  NaN             0                   NaN
# 325             0                  NaN             0                   NaN
# 358             0                  NaN             0                   NaN
# 380             0                  NaN             0                   NaN
# 408             0                  NaN             0                   NaN
# 491             0                  NaN             0                   NaN
#
#     PS Percentile  EV/EBITDA EV/EBITDA Percentile  EV/GP EV/GP Percentile  \
# 6               0        NaN                    0    NaN                0
# 28              0        NaN                    0    NaN                0
# 40              0        NaN                    0    NaN                0
# 88              0        NaN                    0    NaN                0
# 118             0        NaN                    0    NaN                0
# 121             0        NaN                    0    NaN                0
# 135             0        NaN                    0    NaN                0
# 164             0        NaN                    0    NaN                0
# 183             0        NaN                    0    NaN                0
# 185             0        NaN                    0    NaN                0
# 192             0        NaN                    0    NaN                0
# 252             0        NaN                    0    NaN                0
# 263             0        NaN                    0    NaN                0
# 323             0        NaN                    0    NaN                0
# 324             0        NaN                    0    NaN                0
# 325             0        NaN                    0    NaN                0
# 358             0        NaN                    0    NaN                0
# 380             0        NaN                    0    NaN                0
# 408             0        NaN                    0    NaN                0
# 491             0        NaN                    0    NaN                0
#
#     RV Score
# 6          0
# 28         0
# 40         0
# 88         0
# 118        0
# 121        0
# 135        0
# 164        0
# 183        0
# 185        0
# 192        0
# 252        0
# 263        0
# 323        0
# 324        0
# 325        0
# 358        0
# 380        0
# 408        0
# 491        0

# %%
for column in [ 'Price-to-Earnings ratio','Price-to-Book Ratio','Price-to-Sales Ratio','EV/EBITDA','EV/GP']:
    rv_dataframe[column].fillna(rv_dataframe[column].mean(), inplace = True)

# %%
metrics = {
    'Price-to-Earnings ratio':'PE Percentile',
    'Price-to-Book Ratio':'PB Percentile',
    'Price-to-Sales Ratio':'PS Percentile',
    'EV/EBITDA':'EV/EBITDA Percentile',
    'EV/GP':'EV/GP Percentile',  
}
for metric in metrics.keys():
    for row in rv_dataframe.index:
        rv_dataframe.loc[row, metrics[metric]] = score(rv_dataframe[metric], rv_dataframe.loc[row, metric])/100
    
rv_dataframe
# Out:
#     Ticker   Price Number of Shares to Buy  Price-to-Earnings ratio  \
# 0        A  117.68                       0                    25.92
# 1      AAL   14.85                       0                     3.46
# 2      AAP   67.44                       0                    10.02
# 3     AAPL  177.21                       0                    29.78
# 4     ABBV  148.78                       0                    30.55
# ..     ...     ...                     ...                      ...
# 496    YUM  129.08                       0                    26.08
# 497    ZBH  115.53                       0                    48.14
# 498   ZBRA  269.60                       0                    21.59
# 499   ZION   32.94                       0                     3.42
# 500    ZTS  181.72                       0                    38.26
#
#     PE Percentile  Price-to-Book Ratio PB Percentile  Price-to-Sales Ratio  \
# 0        0.630739                 6.07      0.776447                4.9900
# 1          0.0998                -2.26      0.061876                0.1873
# 2        0.203593                 1.54      0.241517                0.3620
# 3        0.718563                45.61      0.972056                7.1600
# 4        0.740519                20.60      0.954092                4.7300
# ..            ...                  ...           ...                   ...
# 496      0.634731                -4.28      0.057884                5.1600
# 497      0.892216                 2.03      0.341317                3.5000
# 498       0.54491                 4.59      0.641717                2.5000
# 499      0.097804                 1.06      0.136727                1.0900
# 500      0.826347                18.00      0.938124               10.1200
#
#     PS Percentile  EV/EBITDA EV/EBITDA Percentile      EV/GP EV/GP Percentile  \
# 0        0.782435  18.499682             0.744511   9.541080         0.734531
# 1        0.013972   4.696440              0.06986   0.614247         0.017964
# 2        0.047904   6.424212             0.131737   1.162786         0.073852
# 3        0.882236  22.555575             0.848303  16.760511         0.946108
# 4        0.774451  11.491793             0.365269   8.218842         0.648703
# ..            ...        ...                  ...        ...              ...
# 496      0.794411  20.026384             0.800399   9.003282         0.704591
# 497      0.632735  16.083017             0.610778   5.917498         0.429142
# 498       0.51497  15.234695             0.566866   6.198576          0.45509
# 499      0.202595   2.744341              0.01996   1.142607          0.06986
# 500       0.94511  27.870221              0.91018  15.271354          0.92016
#
#     RV Score
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 496        0
# 497        0
# 498        0
# 499        0
# 500        0
#
# [501 rows x 14 columns]

# %%
for row in rv_dataframe.index:
    value_percentiles = []
    for metric in metrics.keys():
        value_percentiles.append(rv_dataframe.loc[row, metrics[metric]])
    rv_dataframe.loc[row, 'RV Score'] = mean(value_percentiles)
rv_dataframe
# Out:
#     Ticker   Price Number of Shares to Buy  Price-to-Earnings ratio  \
# 0        A  117.68                       0                    25.92
# 1      AAL   14.85                       0                     3.46
# 2      AAP   67.44                       0                    10.02
# 3     AAPL  177.21                       0                    29.78
# 4     ABBV  148.78                       0                    30.55
# ..     ...     ...                     ...                      ...
# 496    YUM  129.08                       0                    26.08
# 497    ZBH  115.53                       0                    48.14
# 498   ZBRA  269.60                       0                    21.59
# 499   ZION   32.94                       0                     3.42
# 500    ZTS  181.72                       0                    38.26
#
#     PE Percentile  Price-to-Book Ratio PB Percentile  Price-to-Sales Ratio  \
# 0        0.630739                 6.07      0.776447                4.9900
# 1          0.0998                -2.26      0.061876                0.1873
# 2        0.203593                 1.54      0.241517                0.3620
# 3        0.718563                45.61      0.972056                7.1600
# 4        0.740519                20.60      0.954092                4.7300
# ..            ...                  ...           ...                   ...
# 496      0.634731                -4.28      0.057884                5.1600
# 497      0.892216                 2.03      0.341317                3.5000
# 498       0.54491                 4.59      0.641717                2.5000
# 499      0.097804                 1.06      0.136727                1.0900
# 500      0.826347                18.00      0.938124               10.1200
#
#     PS Percentile  EV/EBITDA EV/EBITDA Percentile      EV/GP EV/GP Percentile  \
# 0        0.782435  18.499682             0.744511   9.541080         0.734531
# 1        0.013972   4.696440              0.06986   0.614247         0.017964
# 2        0.047904   6.424212             0.131737   1.162786         0.073852
# 3        0.882236  22.555575             0.848303  16.760511         0.946108
# 4        0.774451  11.491793             0.365269   8.218842         0.648703
# ..            ...        ...                  ...        ...              ...
# 496      0.794411  20.026384             0.800399   9.003282         0.704591
# 497      0.632735  16.083017             0.610778   5.917498         0.429142
# 498       0.51497  15.234695             0.566866   6.198576          0.45509
# 499      0.202595   2.744341              0.01996   1.142607          0.06986
# 500       0.94511  27.870221              0.91018  15.271354          0.92016
#
#      RV Score
# 0    0.733733
# 1    0.052695
# 2    0.139721
# 3    0.873453
# 4    0.696607
# ..        ...
# 496  0.598403
# 497  0.581238
# 498  0.544711
# 499  0.105389
# 500  0.907984
#
# [501 rows x 14 columns]

# %%
rv_dataframe.sort_values('RV Score', ascending = True, inplace = True)
rv_dataframe = rv_dataframe[:50]
rv_dataframe.reset_index(drop = True, inplace = True)
rv_dataframe
# Out:
#    Ticker    Price Number of Shares to Buy  Price-to-Earnings ratio  \
# 0     FRC    3.510                       0                     0.43
# 1     LNC   25.325                       0                    -1.43
# 2     AAL   14.850                       0                     3.46
# 3      GM   32.930                       0                     4.59
# 4     WBA   26.435                       0                    -6.88
# 5     XRX   15.530                       0                    -9.14
# 6       C   41.070                       0                     6.54
# 7     KSS   25.915                       0                  -157.54
# 8     SYF   32.025                       0                     5.92
# 9     WFC   41.530                       0                    10.38
# 10    UNM   48.445                       0                     6.72
# 11    DXC   20.400                       0                    -7.18
# 12    GPS    9.545                       0                   -60.26
# 13   ZION   32.940                       0                     3.42
# 14    AIG   57.380                       0                     9.61
# 15      F   11.865                       0                    11.52
# 16    CFG   26.850                       0                     6.09
# 17    UAL   49.505                       0                     6.15
# 18    COF  101.180                       0                     7.75
# 19      L   61.420                       0                    11.74
# 20    KEY   10.425                       0                     6.95
# 21    MHK   96.610                       0                   -19.32
# 22    VLO  131.110                       0                     4.51
# 23    WRK   31.445                       0                    -5.70
# 24    TFC   28.105                       0                     6.49
# 25    ALL  105.300                       0                   -10.14
# 26     UA    6.540                       0                     7.73
# 27      T   14.200                       0                   -11.83
# 28    UAA    7.195                       0                     8.50
# 29    CMA   45.310                       0                     4.74
# 30    PSX  112.850                       0                     4.86
# 31    AAP   67.440                       0                    10.02
# 32   DISH    6.300                       0                     2.27
# 33    MOS   38.915                       0                     6.12
# 34    HIG   71.130                       0                    11.45
# 35    STT   66.280                       0                     8.97
# 36    MPC  142.950                       0                     5.12
# 37    UHS  130.130                       0                    13.51
# 38    HPQ   31.025                       0                    11.75
# 39    CNC   63.900                       0                    13.28
# 40   HBAN   10.705                       0                     6.91
# 41   FITB   24.870                       0                     7.09
# 42    BAC   28.480                       0                     8.21
# 43    BWA   39.450                       0                    11.47
# 44    DFS   89.300                       0                     6.20
# 45     BK   43.040                       0                    12.58
# 46     RL  113.090                       0                    14.46
# 47    MTB  125.880                       0                     7.48
# 48     GS  319.590                       0                    13.61
# 49    FOX   30.605                       0                    13.14
#
#    PE Percentile  Price-to-Book Ratio PB Percentile  Price-to-Sales Ratio  \
# 0       0.093812               0.0456      0.063872                0.0934
# 1       0.083832               0.9091      0.103792                0.2858
# 2         0.0998              -2.2600      0.061876                0.1873
# 3       0.107784               0.6388      0.077844                0.2697
# 4       0.065868               1.0800      0.142715                0.1677
# 5       0.053892               0.7160      0.081836                0.3383
# 6       0.133733               0.4345      0.067864                0.6182
# 7       0.011976               0.8532      0.093812                0.1768
# 8       0.117764               1.0900      0.147705                0.6775
# 9       0.211577               0.4819      0.071856                0.7679
# 10      0.139721               1.0400      0.128743                0.7921
dataframe
# Out:
#    Ticker    Price Number of Shares to Buy  Price-to-Earnings ratio  \
# 0     FRC    3.510                    5698                     0.43
# 1     LNC   25.325                     789                    -1.43
# 2     AAL   14.850                    1346                     3.46
# 3      GM   32.930                     607                     4.59
# 4     WBA   26.435                     756                    -6.88
# 5     XRX   15.530                    1287                    -9.14
# 6       C   41.070                     486                     6.54
# 7     KSS   25.915                     771                  -157.54
# 8     SYF   32.025                     624                     5.92
# 9     WFC   41.530                     481                    10.38
# 10    UNM   48.445                     412                     6.72
# 11    DXC   20.400                     980                    -7.18
# 12    GPS    9.545                    2095                   -60.26
# 13   ZION   32.940                     607                     3.42
# 14    AIG   57.380                     348                     9.61
# 15      F   11.865                    1685                    11.52
# 16    CFG   26.850                     744                     6.09
# 17    UAL   49.505                     403                     6.15
# 18    COF  101.180                     197                     7.75
# 19      L   61.420                     325                    11.74
# 20    KEY   10.425                    1918                     6.95
# 21    MHK   96.610                     207                   -19.32
# 22    VLO  131.110                     152                     4.51
# 23    WRK   31.445                     636                    -5.70
# 24    TFC   28.105                     711                     6.49
# 25    ALL  105.300                     189                   -10.14
# 26     UA    6.540                    3058                     7.73
# 27      T   14.200                    1408                   -11.83
# 28    UAA    7.195                    2779                     8.50
# 29    CMA   45.310                     441                     4.74
# 30    PSX  112.850                     177                     4.86
# 31    AAP   67.440                     296                    10.02
# 32   DISH    6.300                    3174                     2.27
# 33    MOS   38.915                     513                     6.12
# 34    HIG   71.130                     281                    11.45
# 35    STT   66.280                     301                     8.97
# 36    MPC  142.950                     139                     5.12
# 37    UHS  130.130                     153                    13.51
# 38    HPQ   31.025                     644                    11.75
# 39    CNC   63.900                     312                    13.28
# 40   HBAN   10.705                    1868                     6.91
# 41   FITB   24.870                     804                     7.09
# 42    BAC   28.480                     702                     8.21
# 43    BWA   39.450                     506                    11.47
# 44    DFS   89.300                     223                     6.20
# 45     BK   43.040                     464                    12.58
# 46     RL  113.090                     176                    14.46
# 47    MTB  125.880                     158                     7.48
# 48     GS  319.590                      62                    13.61
# 49    FOX   30.605                     653                    13.14
#
#    PE Percentile  Price-to-Book Ratio PB Percentile  Price-to-Sales Ratio  \
# 0       0.093812               0.0456      0.063872                0.0934
# 1       0.083832               0.9091      0.103792                0.2858
# 2         0.0998              -2.2600      0.061876                0.1873
# 3       0.107784               0.6388      0.077844                0.2697
# 4       0.065868               1.0800      0.142715                0.1677
# 5       0.053892               0.7160      0.081836                0.3383
# 6       0.133733               0.4345      0.067864                0.6182
# 7       0.011976               0.8532      0.093812                0.1768
# 8       0.117764               1.0900      0.147705                0.6775
# 9       0.211577               0.4819      0.071856                0.7679
# 10      0.139721               1.0400      0.128743                0.7921
# 11      0.063872               1.2700      0.164671                0.2948
# 12      0.021956               1.7300      0.287425                0.2450
# 13      0.097804               1.0600      0.136727                1.0900
# 14      0.191617               0.9803      0.113772                0.8164
# 15      0.234531               1.0800      0.142715                0.2771
# 16      0.121756               0.6008      0.075848                1.1600
# 17      0.125749               2.1100      0.355289                0.3199
# 18      0.157685               0.7298      0.083832                0.8940
# 19      0.239521               0.9528       0.10978                0.9170
# 20      0.145709               0.8985        0.0998                1.0700
# 21       0.03992               0.7541      0.085828                0.5464
# 28      0.068862   7.000516             0.154691  1.087790         0.062874
# 29      0.262475   3.555863             0.033932  1.336687         0.103792
# 30      0.043912   3.878377             0.045908  3.202393         0.219561
# 31      0.047904   6.424212             0.131737  1.162786         0.073852
# 32      0.005988   9.667756             0.253493  4.492116         0.307385
# 33      0.125749   4.170001             0.053892  4.346602         0.303393
# 34      0.159681   4.849736             0.075848  0.927122           0.0499
# 35      0.262475   5.929542             0.115768  1.301826         0.095808
# 36        0.0499   3.480283              0.02994  3.036284         0.209581
# 37      0.091816   7.525036             0.175649  0.913826         0.045908
# 38      0.085828   8.355013             0.203593  3.481071         0.243513
# 39       0.01996  10.834422             0.331337  0.367020         0.005988
# 40      0.347305   5.248751              0.08982  1.728583         0.141717
# 41      0.321357   5.347960             0.095808  1.673998         0.133733
# 42      0.317365   6.556932             0.137725  1.596438         0.123752
# 43      0.087824   5.358475             0.097804  3.923845         0.281437
# 44      0.259481   4.354925              0.05988  1.668919         0.131737
# 45      0.255489   7.360588             0.167665  1.256203          0.08982
# 46       0.10978   4.422846             0.063872  1.056175         0.057884
# 47      0.399202   5.310360             0.093812  1.961542         0.157685
# 48      0.234531   7.091495             0.161677  1.194186         0.075848
# 49      0.194611   5.877469             0.112774  1.251322         0.086826
#
#     RV Score
# 0   0.035529
# 1   0.047505
# 2   0.052695
# 3   0.054691
# 4   0.062874
# 5   0.064671
# 6   0.071457
# 7   0.077046
# 8    0.08982
# 9   0.093014
# 10  0.096008
# 11  0.098403
# 12  0.102196
# 13  0.105389
# 14  0.105788
# 15   0.10978
# 16   0.11018
# 17  0.114571
# 18  0.115369
# 19  0.118563
# 20   0.12016
# 21  0.121756
# 22  0.125549
# 23  0.126148
# 24  0.126547
# 25  0.126547
# 26  0.128743
# 27  0.130539
# 28  0.132335
# 29  0.133134
# 30  0.139721
# 31  0.139721
# 32  0.145709
# 33  0.148703
# 34  0.152894
# 35  0.153892
# 36  0.156886
# 37  0.158084
# 38  0.163273
# 39  0.166068
# 40  0.168862
# 41  0.169661
# 42   0.17006
# 43  0.172056
# 44  0.176248
# 45  0.176447
# 46  0.177445
# 47   0.18004
# 48  0.181038
# 49  0.182236

# %%
writer = pd.ExcelWriter('value_strategy.xlsx', engine='xlsxwriter')
rv_dataframe.to_excel(writer, sheet_name='Value Strategy', index = False)

background_color = '#0a0a23'
font_color = '#ffffff'

string_format = writer.book.add_format(
    {
        'font_color': font_color,
        'bg_color': background_color,
        'border': 1
    }
)

dollar_format = writer.book.add_format(
    {
        'num_format': '$0.00',
        'font_color': font_color,
        'bg_color': background_color,
        'border': 1
    }
)

float_format = writer.book.add_format(
    {
        'num_format': '0.0',
        'font_color': font_color,
        'bg_color': background_color,
        'border': 1
    }
)

integer_format = writer.book.add_format(
    {
        'num_format': '0',
        'font_color': font_color,
        'bg_color': background_color,
        'border': 1
    }
)

percent_format = writer.book.add_format(
    {
        'num_format': '0.0%',
        'font_color': font_color,
        'bg_color': background_color,
        'border': 1
    }
)

# %%
column_formats = {
    'A':['Ticker', string_format],
    'B':['Price', dollar_format],
    'C':['Number of Shares to Buy', integer_format],
    'D':['Price-to-Earnings ratio', float_format],
    'E':['PE Percentile', percent_format],
    'F':['Price-to-Book Ratio', float_format],
    'G':['PB Percentile', percent_format],
    'H':['Price-to-Sales Ratio', float_format],
    'I':['PS Percentile', percent_format],
    'J':['EV/EBITDA', float_format],
    'K':['EV/EBITDA Percentile',percent_format],
    'L':['EV/GP', float_format],
    'M':['EV/GP Percentile', percent_format],
    'N':['RV Score', percent_format]
}

for column in column_formats.keys():
    writer.sheets['Value Strategy'].set_column(f'{column}:{column}', 22, column_formats[column][1])
    writer.sheets['Value Strategy'].write(f'{column}1', column_formats[column][0], column_formats[column][1])
    
writer.save()
